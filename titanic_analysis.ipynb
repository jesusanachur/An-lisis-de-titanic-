# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ruta = r'C:\Users\DELL\Desktop/train.csv'
df = pd.read_csv(ruta)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df["first_name"] = df["Name"].str.split(",").str.get(1).str.split(".").str.get(1).str.strip()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
df["title"] = df["Name"].str.split(",").str.get(1).str.split(".").str.get(0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
df['title'].unique()
# Out:
# array([' Mr', ' Mrs', ' Miss', ' Master', ' Don', ' Rev', ' Dr', ' Mme',
#        ' Ms', ' Major', ' Lady', ' Sir', ' Mlle', ' Col', ' Capt',
#        ' the Countess', ' Jonkheer'], dtype=object)

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex']=df['Sex'].map({'male': 'M','female':'f'})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   M  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0      1      0
# 2                             Heikkinen, Miss. Laina   f  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0      1      0
# 4                           Allen, Mr. William Henry   M  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  \
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
#
# ...

# %%
df[['Survived','title']].groupby(by='title').sum()
# Out:
#               Survived
# title
# Capt                 0
# Col                  1
# Don                  0
# Dr                   3
# Jonkheer             0
# Lady                 1
# Major                1
# Master              23
# Miss               127
# Mlle                 2
# Mme                  1
# Mr                  81
# Mrs                 99
# Ms                   1
# Rev                  0
# Sir                  1
# the Countess         1

# %%
df['Survived_str'] = df['Survived'].map({0: 'Murio', 1: 'Vivo'})
df[['Survived_str','title']].groupby(by=['title','Survived_str']).agg(
    numero=('title', 'count'),
)
# Out:
#                            numero
# title        Survived_str
# Capt         Murio              1
# Col          Murio              1
#              Vivo               1
# Don          Murio              1
# Dr           Murio              4
#              Vivo               3
# Jonkheer     Murio              1
# Lady         Vivo               1
# Major        Murio              1
#              Vivo               1
# Master       Murio             17
#              Vivo              23
# Miss         Murio             55
#              Vivo             127
# Mlle         Vivo               2
# Mme          Vivo               1
# Mr           Murio            436
#              Vivo              81
# Mrs          Murio             26
#              Vivo              99
# Ms           Vivo               1
# Rev          Murio              6
# Sir          Vivo               1
# the Countess Vivo               1

# %%
df['Survived_str'] = df['Survived'].map({0: 'Murio', 1: 'Vivo'})

# %%
df[['Survived_str','Sex']].groupby(by=['Sex','Survived_str']).agg(
    numero=('Sex', 'count'),
)
# Out:
#                   numero
# Sex Survived_str
# M   Murio            468
#     Vivo             109
# f   Murio             81
#     Vivo             233

# %%
df[['Survived_str', 'Pclass', 'Sex']].groupby(by=['Sex', 'Pclass', 'Survived_str']).agg(
    numero=('Sex', 'count'),
)
# Out:
#                          numero
# Sex Pclass Survived_str
# M   1      Murio             77
#            Vivo              45
#     2      Murio             91
#            Vivo              17
#     3      Murio            300
#            Vivo              47
# f   1      Murio              3
#            Vivo              91
#     2      Murio              6
#            Vivo              70
#     3      Murio             72
#            Vivo              72

# %%
# Calculate the percentage of each group (Sex, Pclass, Survived_str) within each Pclass
grouped = df.groupby(['Sex', 'Pclass', 'Survived_str']).size().reset_index(name='count')
total_per_pclass = df['Pclass'].value_counts().sort_index()
grouped['percentage'] = grouped.apply(lambda row: row['count'] / total_per_pclass[row['Pclass']] * 100, axis=1)
grouped
# Out:
#    Sex  Pclass Survived_str  count  percentage
# 0    M       1        Murio     77   35.648148
# 1    M       1         Vivo     45   20.833333
# 2    M       2        Murio     91   49.456522
# 3    M       2         Vivo     17    9.239130
# 4    M       3        Murio    300   61.099796
# 5    M       3         Vivo     47    9.572301
# 6    f       1        Murio      3    1.388889
# 7    f       1         Vivo     91   42.129630
# 8    f       2        Murio      6    3.260870
# 9    f       2         Vivo     70   38.043478
# 10   f       3        Murio     72   14.663951
# 11   f       3         Vivo     72   14.663951

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Survived', data=df)
plt.title('Distribución de Supervivencia')
plt.xlabel('Sobrevivió (0 = No, 1 = Sí)')
plt.ylabel('Cantidad de Pasajeros')
plt.show()

# Porcentaje de supervivencia
survival_rate = df['Survived'].mean() * 100
print(f'Porcentaje de supervivencia: {survival_rate:.2f}%')
# Out:
# Porcentaje de supervivencia: 38.38%

# %%
# Gráfico de supervivencia por género
plt.figure(figsize=(10, 6))
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title('Supervivencia por Género')
plt.xlabel('Género')
plt.ylabel('Cantidad de Pasajeros')
plt.legend(['No Sobrevivió', 'Sobrevivió'])
plt.show()

# Tasa de supervivencia por género
survival_by_sex = df.groupby('Sex')['Survived'].mean() * 100
print('Tasa de supervivencia por género:')
display(survival_by_sex)
# Out:
# Tasa de supervivencia por género:
# Sex
# M    18.890815
# f    74.203822
# Name: Survived, dtype: float64

# %%
# Gráfico de supervivencia por clase
plt.figure(figsize=(10, 6))
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title('Supervivencia por Clase de Ticket')
plt.xlabel('Clase de Ticket')
plt.ylabel('Cantidad de Pasajeros')
plt.legend(['No Sobrevivió', 'Sobrevivió'])
plt.show()

# Tasa de supervivencia por clase
survival_by_class = df.groupby('Pclass')['Survived'].mean() * 100
print('Tasa de supervivencia por clase de ticket:')
display(survival_by_class)
# Out:
# Tasa de supervivencia por clase de ticket:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df.dropna(subset=['Age']), x='Age', bins=30, kde=True)
plt.title('Distribución de Edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# Boxplot de edades por supervivencia
plt.figure(figsize=(10, 6))
sns.boxplot(x='Survived', y='Age', data=df.dropna(subset=['Age']))
plt.title('Distribución de Edades por Supervivencia')
plt.xlabel('Sobrevivió (0 = No, 1 = Sí)')
plt.ylabel('Edad')
plt.show()

# %%
# Gráfico de supervivencia por puerto de embarque
plt.figure(figsize=(10, 6))
sns.countplot(x='Embarked', hue='Survived', data=df)
plt.title('Supervivencia por Puerto de Embarque')
plt.xlabel('Puerto de Embarque')
plt.ylabel('Cantidad de Pasajeros')
plt.legend(['No Sobrevivió', 'Sobrevivió'])
plt.show()

# Tasa de supervivencia por puerto
survival_by_embarked = df.groupby('Embarked')['Survived'].mean() * 100
print('Tasa de supervivencia por puerto de embarque:')
display(survival_by_embarked)
# Out:
# Tasa de supervivencia por puerto de embarque:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %%
# Crear una columna para el tamaño de la familia
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# Gráfico de supervivencia por tamaño de familia
plt.figure(figsize=(12, 6))
sns.countplot(x='FamilySize', hue='Survived', data=df)
plt.title('Supervivencia por Tamaño de Familia')
plt.xlabel('Tamaño de Familia')
plt.ylabel('Cantidad de Pasajeros')
plt.legend(['No Sobrevivió', 'Sobrevivió'])
plt.show()

# Tasa de supervivencia por tamaño de familia
survival_by_family = df.groupby('FamilySize')['Survived'].mean() * 100
print('Tasa de supervivencia por tamaño de familia:')
display(survival_by_family)
# Out:
# Tasa de supervivencia por tamaño de familia:
# FamilySize
# 1     30.353818
# 2     55.279503
# 3     57.843137
# 4     72.413793
# 5     20.000000
# 6     13.636364
# 7     33.333333
# 8      0.000000
# 11     0.000000
# Name: Survived, dtype: float64
